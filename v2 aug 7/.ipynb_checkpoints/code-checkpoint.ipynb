# %%
from pycaret.classification import *
import pandas as pd

df_players = pd.read_csv('data.csv')
setup(data = df_players,target = 'y_better_role')
# Out:
# <style type="text/css">
# #T_59653_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_59653">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59653_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_59653_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59653_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59653_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_59653_row0_col1" class="data row0 col1" >3415</td>
#     </tr>
#     <tr>
#       <th id="T_59653_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59653_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_59653_row1_col1" class="data row1 col1" >y_better_role</td>
#     </tr>
#     <tr>
#       <th id="T_59653_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Train Results
best_model = compare_models(errors="raise", fold=3)
# Out:
# <style type="text/css">
# #T_008a9 th {
#   text-align: left;
# }
# ...

# %%
# Test Results
predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_50bbb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50bbb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_50bbb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_50bbb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_50bbb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_50bbb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_50bbb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_50bbb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_50bbb_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50bbb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50bbb_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
# ...

# %%
#To retrieve a specific model
#rt = create_model(best_specific)

# To tune the model
#tuned_rt = tune_model(rt, n_iter = 10)

# To generate predictions for the tuned model
#pred_holdout = predict_model(catboost)

# To save predictions to CSV file
# pred_holdout.to_csv('predictions.csv')

# %%
# X variable(s) that was selected for modelling
# In this case only 1 variable was used for modelling
# To set a fixed number of features to be selected, use n_features_to_select in setup() call
#get_config('X_train_transformed')

# %%
#get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}
